# %% [markdown]
# # DATA SET 1 Processing

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing the libraries used
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data Acquisition - loading the raw files
df1 = pd.read_excel(r'D:\Courses\DIGICROME\NextHikesINTERNSHIP\Project 2- Data Wrangling\dataset_1.xlsx')

# Load the Excel file
#excel_file = "dataset_1.xlsx" 
 # Replace with your Excel file name
#df =  pd.read_excel(excel_file)

# Save as CSV
#csv_file = "output.csv"   # Replace with your desired output file name
#df.to_csv(csv_file, index=False)

#print(f"Excel file '{excel_file}' has been converted to CSV as '{csv_file}'.")

# %%
# Exploratory Data Analysis 
print(df1.head())
print(df1.isnull().sum())
print(df1.describe())
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# ...

# %%
df1.head() #print the top 5 rows of raw dataset 1
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df1.tail() #print the last 5 rows of raw dataset 1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
df1.shape #no of rows and columns
# Out:
# (610, 10)

# %%
df1.columns #names of the columns of dataset 1
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %%
df1.dtypes #printing the datatypes of the columns
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# dtype: object

# %%
#unique values in column
print("unique values in date column: ",df1['dteday'].nunique())
print("unique values in season column: ",df1['season'].nunique())
print("unique values in year column: ",df1['yr'].nunique())
print("unique values in month column: ",df1['mnth'].nunique())
print("unique values in hour column: ",df1['hr'].nunique())
print("unique values in holiday column: ",df1['holiday'].nunique())
print("unique values in weekday column: ",df1['weekday'].nunique())
print("unique values in weathersit column: ",df1['weathersit'].nunique())
print("unique values in temp column: ",df1['temp'].nunique())
# Out:
# unique values in date column:  28
# unique values in season column:  1
# unique values in year column:  1
# unique values in month column:  1
# unique values in hour column:  24
# unique values in holiday column:  2
# unique values in weekday column:  7
# unique values in weathersit column:  4
# unique values in temp column:  23

# %%
df1.isnull().sum() #null values
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
df1.duplicated().sum() #duplicate values
# Out:
# 0

# %%
df1.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp
# count  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885
# min      0.000000    0.000000    1.000000    0.020000
# 25%      6.000000    1.000000    1.000000    0.160000
# 50%     12.000000    3.000000    1.000000    0.200000
# ...

# %%
df1.info() #DT Summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
#convert datatype
df1['dteday']=pd.to_datetime(df1['dteday'], format='%d-%m-%Y')

# %%
df1.drop_duplicates() # to delete the duplicate rows
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
df1.fillna(df1.mean())
# Data Wrangling
df1.fillna(df1.mean(), inplace=True)  # Fill missing values with column mean
df1.drop_duplicates(inplace=True)     # Remove duplicates

# %%
df1.rename(columns={'yr': 'year','mnth': 'month','hr': 'hour'}, inplace=True)
print(df1.describe())
# Out:
#           instant                         dteday  season   year  month  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#              hour     weekday  weathersit        temp
# count  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885
# min      0.000000    0.000000    1.000000    0.020000
# 25%      6.000000    1.000000    1.000000    0.160000
# 50%     12.000000    3.000000    1.000000    0.200000
# ...

# %%
# Basic Plotting (Matplotlib)
plt.plot(df1['temp'])
plt.title('Simple Line Plot')
plt.xlabel('count')
plt.ylabel('temp')
plt.show()

# %%
plt.plot(df1['weathersit'])
plt.title('Simple Line Plot')
plt.xlabel('count')
plt.ylabel('weathersit')
plt.show()

# %%
file_path = r'C:\Users\LENOVO\OneDrive\Documents\Courses\DIGICROME\NextHikesINTERNSHIP\Project 2- Data Wrangling\dataset_1.xlsx'

try:
    # Attempt to read the file
    df1 = pd.read_excel(file_path)
    print(df1.head())
except PermissionError:
    print(f"Permission denied: Unable to access the file at {file_path}. Please check file permissions.")
except FileNotFoundError:
    print(f"File not found: {file_path}. Please check the file path.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
#Calculate avg temp from temp column to draw a line graph
daily_avg_temp=df1.groupby('dteday')['temp'].mean()

# %%
df1.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
#line graph
plt.figure(figsize=(14,6))
plt.plot(daily_avg_temp.index, daily_avg_temp.values, marker='o', linestyle='-', color='black')

for x,y in zip(daily_avg_temp.index,daily_avg_temp.values):
    plt.text(x,y, f'{y:.2f}', fontsize=10, color='blue')

plt.title('Monthwise daily average temp - January')
plt.xlabel('Date')
plt.ylabel('Average temperature')
plt.grid()

# %% [markdown]
# # DATA SET 2

# %%
# Data Acquisition - loading the raw files
df2 = pd.read_excel(r'D:\Courses\DIGICROME\NextHikesINTERNSHIP\Project 2- Data Wrangling\dataset_2.xlsx')

# %%
# Exploratory Data Analysis 
print(df2.head())
print(df2.isnull().sum())
print(df2.describe())
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# ...

# %%
df2.head() #print the top 5 rows of raw dataset 2
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df2.tail()
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %%
df2.shape
# Out:
# (610, 8)

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'instant', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# Unnamed: 0      int64
# instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df2.drop(columns=['Unnamed: 0'], inplace=True)

# %%
print("unique values in instant column: ", df2['instant'].nunique())
print("unique values in atemp column: ", df2['atemp'].nunique())
print("unique values in hum column: ", df2['hum'].nunique())
print("unique values in windspeed column: ", df2['windspeed'].nunique())
print("unique values in casual column: ", df2['casual'].nunique())
print("unique values in registered column: ", df2['registered'].nunique())
print("unique values in cnt column: ", df2['cnt'].nunique())
# Out:
# unique values in instant column:  610
# unique values in atemp column:  29
# unique values in hum column:  61
# unique values in windspeed column:  20
# unique values in casual column:  32
# unique values in registered column:  150
# unique values in cnt column:  165

# %%
df2.isnull().sum() #null values
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df2.duplicated().sum() #duplicate values
# Out:
# 0

# %%
df2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  599.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078836    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.242400    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
df2.info() #DT Summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instant       610 non-null    int64
#  1   atemperature  599 non-null    float64
#  2   hum           610 non-null    float64
#  3   windspeed     610 non-null    float64
#  4   casual        610 non-null    int64
#  5   registered    610 non-null    int64
#  6   cnt           610 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 33.5 KB

# %%
df2.drop_duplicates() # to delete the duplicate rows
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
df2.fillna(df2.mean())
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
df2.rename(columns={'atemp': 'temp'}, inplace=True)
print(df2.describe())
# Out:
#           instant         hum   windspeed      casual  registered         cnt
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.562475    0.204851    4.501639   51.068852   55.570492
# std    176.236111    0.175440    0.121806    6.319945   47.021204   49.316802
# min      1.000000    0.210000    0.000000    0.000000    0.000000    1.000000
# 25%    153.250000    0.432500    0.104500    0.000000   14.000000   16.000000
# 50%    305.500000    0.520000    0.194000    2.000000   43.000000   47.000000
# 75%    457.750000    0.690000    0.283600    6.000000   70.000000   79.750000
# max    610.000000    1.000000    0.582100   47.000000  247.000000  249.000000

# %%
# Basic Plotting (Matplotlib)
plt.plot(df2['temp'])
plt.title('Simple Line Plot')
plt.xlabel('count')
plt.ylabel('temperature')
plt.show()

# %%
# Basic Plotting (Matplotlib)
plt.plot(df2['registered'])
plt.title('Simple Line Plot')
plt.xlabel('mean')
plt.ylabel('registered')
plt.show()

# %%
plt.plot(df2['casual'])
plt.title('Simple Line Plot')
plt.xlabel('count')
plt.ylabel('casual')
plt.show()

# %% [markdown]
# ##### Merging the DATA SET 1 and DATASET 2

# %%
df1.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df2.head()
# Out:
#    instant   atemp   hum  windspeed  casual  registered  cnt
# 0        1  0.2879  0.81        0.0       3          13   16
# 1        2  0.2727  0.80        0.0       8          32   40
# 2        3  0.2727  0.80        0.0       5          27   32
# 3        4  0.2879  0.75        0.0       3          10   13
# 4        5  0.2879  0.75        0.0       0           1    1

# %%
df2.rename(columns={'atemp': 'temp'}, inplace=True)

# %%
df2.describe()
# Out:
#           instant        temp         hum   windspeed      casual  registered  \
# count  610.000000  599.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078836    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.242400    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
df2.duplicated().sum() # duplicate data
# Out:
# 0

# %%
df1['temp'] = df1['temp'].astype(str)
df2['temp'] = df2['temp'].astype(str)

# %%
# # Step 2: Merge the datasets. Perform the merge (inner join by default)
merged_df = pd.merge(df1, df2, on='instant', how= 'inner')

# %%
# Inspect the merged dataset
merged_df
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
# Step 3: Save the merged dataset to a new CSV file
merged_df.to_csv('merged_data.csv', index=False)

# %%
df_combined = pd.concat([df1, df2], ignore_index=True)

# %%
df_combined.describe()
# Out:
#            instant                         dteday  season     yr   mnth  \
# count  1220.000000                            610   610.0  610.0  610.0
# mean    305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min       1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%     153.000000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%     305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%     458.000000            2011-01-21 00:00:00     1.0    0.0    1.0
# max     610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std     176.163809                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp  Unnamed: 0       atemp  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  599.000000
# mean    11.795082    2.977049    1.477049    0.196885  304.500000    0.199935
# min      0.000000    0.000000    1.000000    0.020000    0.000000    0.000000
# ...

# %%
df_combined
# Out:
#       instant     dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0           1 2011-01-01     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1           2 2011-01-01     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2           3 2011-01-01     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3           4 2011-01-01     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4           5 2011-01-01     1.0  0.0   1.0  4.0   False      6.0         1.0
# ...       ...        ...     ...  ...   ...  ...     ...      ...         ...
# 1215      606        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1216      607        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1217      608        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1218      609        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1219      610        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
# ...

# %%
# Step 3: Save the merged dataset to a new CSV file
df_combined.to_csv('merged_dataset.csv', index=False)

# %% [markdown]
# # MERGED FILE PROCESSING

# %%
df_combined.head()
# Out:
#    instant     dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0        1 2011-01-01     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1        2 2011-01-01     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2        3 2011-01-01     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3        4 2011-01-01     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4        5 2011-01-01     1.0  0.0   1.0  4.0   False      6.0         1.0
#
#    temp  hum  windspeed  casual  registered  cnt
# 0  0.24  NaN        NaN     NaN         NaN  NaN
# 1  0.22  NaN        NaN     NaN         NaN  NaN
# 2  0.22  NaN        NaN     NaN         NaN  NaN
# 3  0.24  NaN        NaN     NaN         NaN  NaN
# 4  0.24  NaN        NaN     NaN         NaN  NaN

# %%
df_combined.tail()
# Out:
#       instant dteday  season  yr  mnth  hr holiday  weekday  weathersit  \
# 1215      606    NaT     NaN NaN   NaN NaN     NaN      NaN         NaN
# 1216      607    NaT     NaN NaN   NaN NaN     NaN      NaN         NaN
# 1217      608    NaT     NaN NaN   NaN NaN     NaN      NaN         NaN
# 1218      609    NaT     NaN NaN   NaN NaN     NaN      NaN         NaN
# 1219      610    NaT     NaN NaN   NaN NaN     NaN      NaN         NaN
#
#         temp   hum  windspeed  casual  registered   cnt
# 1215  0.2121  0.93     0.1045     0.0        30.0  30.0
# 1216  0.2121  0.93     0.1045     1.0        28.0  29.0
# 1217  0.2121  0.93     0.1045     0.0        31.0  31.0
# 1218  0.2727  0.80     0.0000     2.0        36.0  38.0
# 1219  0.2576  0.86     0.0000     1.0        40.0  41.0

# %%
df_combined.shape
# Out:
# (1220, 15)

# %%
df_combined.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'hum', 'windspeed', 'casual', 'registered',
#        'cnt'],
#       dtype='object')

# %%
df_combined.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season               float64
# yr                   float64
# mnth                 float64
# hr                   float64
# holiday               object
# weekday              float64
# weathersit           float64
# temp                 float64
# hum                  float64
# windspeed            float64
# casual               float64
# registered           float64
# cnt                  float64
# dtype: object

# %%
df_combined.info
# Out:
# <bound method DataFrame.info of       instant     dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0           1 2011-01-01     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1           2 2011-01-01     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2           3 2011-01-01     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3           4 2011-01-01     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4           5 2011-01-01     1.0  0.0   1.0  4.0   False      6.0         1.0
# ...       ...        ...     ...  ...   ...  ...     ...      ...         ...
# 1215      606        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1216      607        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1217      608        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1218      609        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1219      610        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
# ...

# %%
print("unique values in instant column: ", df_combined['instant'].nunique())
print("unique values in dteday column: ", df_combined['dteday'].nunique())
print("unique values in season column: ", df_combined['season'].nunique())
print("unique values in year column: ", df_combined['yr'].nunique())
print("unique values in month column: ", df_combined['mnth'].nunique())
print("unique values in casual column: ", df_combined['casual'].nunique())
print("unique values in cnt column: ", df_combined['cnt'].nunique())
# Out:
# unique values in instant column:  610
# unique values in dteday column:  28
# unique values in season column:  1
# unique values in year column:  1
# unique values in month column:  1
# unique values in casual column:  32
# unique values in cnt column:  165

# %%
df_combined.isnull().sum() # Null values
# Out:
# instant         0
# dteday        610
# season        610
# yr            610
# mnth          610
# hr            610
# holiday       610
# weekday       610
# weathersit    610
# temp           11
# hum           610
# windspeed     610
# casual        610
# registered    610
# cnt           610
# dtype: int64

# %%
df_combined.duplicated().sum() # duplicate values
# Out:
# 0

# %%
df_combined.describe
# Out:
# <bound method NDFrame.describe of       instant     dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0           1 2011-01-01     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1           2 2011-01-01     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2           3 2011-01-01     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3           4 2011-01-01     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4           5 2011-01-01     1.0  0.0   1.0  4.0   False      6.0         1.0
# ...       ...        ...     ...  ...   ...  ...     ...      ...         ...
# 1215      606        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1216      607        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1217      608        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1218      609        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 1219      610        NaT     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
# ...

# %%
df_combined['dteday']=pd.to_datetime(df_combined['dteday'], format= '%d-%m-%Y')

# %%
# Calculate the regular count from cnt column
RCount=merged_df.groupby('dteday')['cnt'].sum().reset_index()

plt.figure(figsize=(14,6))
sns.lineplot(x='dteday',y='cnt', data=RCount, marker= 'o', color='black')

for x,y in zip(RCount['dteday'],RCount['cnt']):
    plt.text(x,y, str(y), fontsize=10, color='blue')

plt.title('Total Bike Rentals per day')
plt.xlabel('Date')
plt.ylabel('Total count')
plt.grid()

# %%
# CAlculate total count from cnt column with each weekday
wcount=merged_df.groupby('weekday')['cnt'].sum().reset_index()

wlabels=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

# Apply the lambda function to map the weekday indices to their labels
wcount['weekday'] = wcount['weekday'].apply(lambda x: wlabels[x])
wcount=wcount.set_index('weekday').reindex(wlabels).reset_index()

plt.figure(figsize=(10,5))
sns.barplot(x='weekday', y='cnt', data=wcount, palette='Reds')

for index, value in enumerate(wcount['cnt']):
    plt.text(index, value, str(value), fontsize=10)

plt.xlabel('weekday')
plt.xlabel('Regular count')
plt.title('Total Bike Rentals Per Weekday')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_41236\2213496732.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weekday', y='cnt', data=wcount, palette='Reds')

# %% [markdown]
# # DATA SET 3 Processing

# %%
# Data Acquisition - loading the raw files
df3 = pd.read_excel(r'D:\Courses\DIGICROME\NextHikesINTERNSHIP\Project 2- Data Wrangling\dataset_3.xlsx')

# %%
# Print the dataset 3
print(df3)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
# Exploratory Data Analysis 
print(df3.head())
print(df3.isnull().sum())
print(df3.describe())
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620 2011-01-29       1   0     1   1    False        6           1
# 1      621 2011-01-29       1   0     1   2    False        6           1
# 2      622 2011-01-29       1   0     1   3    False        6           1
# 3      623 2011-01-29       1   0     1   4    False        6           1
# 4      624 2011-01-29       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# ...

# %%
df3.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620 2011-01-29       1   0     1   1    False        6           1
# 1      621 2011-01-29       1   0     1   2    False        6           1
# 2      622 2011-01-29       1   0     1   3    False        6           1
# 3      623 2011-01-29       1   0     1   4    False        6           1
# 4      624 2011-01-29       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
df3.shape
# Out:
# (390, 16)

# %%
df3.tail()
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %%
df3.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df3.dtypes # datatypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
#unique values in column
print("unique values in date column: ",df3['dteday'].nunique())
print("unique values in season column: ",df3['season'].nunique())
print("unique values in year column: ",df3['yr'].nunique())
print("unique values in month column: ",df3['mnth'].nunique())
print("unique values in hour column: ",df3['hr'].nunique())
print("unique values in holiday column: ",df3['holiday'].nunique())
print("unique values in weekday column: ",df3['weekday'].nunique())
print("unique values in weathersit column: ",df3['weathersit'].nunique())
print("unique values in temp column: ",df3['temp'].nunique())
print("unique values in wind speed column: ",df3['windspeed'].nunique())
print("unique values in casual column: ",df3['casual'].nunique())
print("unique values in cnt column: ",df3['cnt'].nunique())
print("unique values in registered column: ",df3['registered'].nunique())
# Out:
# unique values in date column:  18
# unique values in season column:  1
# unique values in year column:  1
# unique values in month column:  2
# unique values in hour column:  24
# unique values in holiday column:  1
# unique values in weekday column:  7
# unique values in weathersit column:  3
# unique values in temp column:  19
# unique values in wind speed column:  20
# unique values in casual column:  36
# unique values in cnt column:  144
# unique values in registered column:  146

# %%
df3.isnull().sum() #null values
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3.duplicated().sum() #duplicate values
# Out:
# 0

# %%
df3.describe()
# Out:
#            instant                         dteday  season     yr        mnth  \
# count   390.000000                            390   390.0  390.0  390.000000
# mean    805.500000  2011-02-05 11:45:13.846153728     1.0    0.0    1.800000
# min     611.000000            2011-01-28 00:00:00     1.0    0.0    1.000000
# 25%     708.250000            2011-02-01 00:00:00     1.0    0.0    2.000000
# 50%     805.500000            2011-02-05 12:00:00     1.0    0.0    2.000000
# 75%     902.750000            2011-02-10 00:00:00     1.0    0.0    2.000000
# max    1000.000000            2011-02-14 00:00:00     1.0    0.0    2.000000
# std     112.727548                            NaN     0.0    0.0    0.400514
#
#                hr     weekday  weathersit        temp       atemp         hum  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean    11.687179    2.989744    1.484615    0.220000    0.230424    0.613769
# ...

# %%
df3.info() #DT Summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
# CAl. the regular count (regcount) from cnt column
hcount=df3.groupby('hr')['cnt'].sum().reset_index()

plt.figure(figsize=(14,6))
sns.lineplot(x='hr', y='cnt', data=hcount, marker='o', color='b')

for x,y in zip(hcount['hr'], hcount['cnt']):
    plt.text(x,y, str(y),fontsize=10,color='black')

plt.xlabel('Hour')
plt.ylabel('Total Count')
plt.title('Total bike rentals per hour')
plt.grid()

# %%
# # Step 2: Merge the datasets. Perform the merge (inner join by default)
#merged_df1 = pd.merge(df_combined, df3, on='instant', how= 'inner')


# Merge and check the result
merged_df1 = pd.merge(df_combined, df3, on='instant', how='inner')
print(f"Rows in merged_df1: {len(merged_df1)}")
# Out:
# Rows in merged_df1: 0

# %%
# MERGE  dataset 3 with df_combined
Final_Dataset= pd.concat([df_combined, df3], ignore_index= True)

# %%
Final_Dataset
# Out:
#       instant     dteday  season   yr  mnth    hr holiday  weekday  \
# 0           1 2011-01-01     1.0  0.0   1.0   0.0   False      6.0
# 1           2 2011-01-01     1.0  0.0   1.0   1.0   False      6.0
# 2           3 2011-01-01     1.0  0.0   1.0   2.0   False      6.0
# 3           4 2011-01-01     1.0  0.0   1.0   3.0   False      6.0
# 4           5 2011-01-01     1.0  0.0   1.0   4.0   False      6.0
# ...       ...        ...     ...  ...   ...   ...     ...      ...
# 1605      615 2011-01-28     1.0  0.0   1.0  20.0   False      5.0
# 1606      616 2011-01-28     1.0  0.0   1.0  21.0   False      5.0
# 1607      617 2011-01-28     1.0  0.0   1.0  22.0   False      5.0
# 1608      618 2011-01-28     1.0  0.0   1.0  23.0   False      5.0
# 1609      619 2011-01-29     1.0  0.0   1.0   0.0   False      6.0
#
#       weathersit  temp  Unnamed: 0   atemp   hum  windspeed  casual  \
# 0            1.0  0.24         NaN     NaN   NaN        NaN     NaN
# ...

# %%
merged_df1
# Out:
# Empty DataFrame
# Columns: [instant, dteday_x, season_x, yr_x, mnth_x, hr_x, holiday_x, weekday_x, weathersit_x, temp_x, Unnamed: 0, atemp_x, hum_x, windspeed_x, casual_x, registered_x, cnt_x, dteday_y, season_y, yr_y, mnth_y, hr_y, holiday_y, weekday_y, weathersit_y, temp_y, atemp_y, hum_y, windspeed_y, casual_y, registered_y, cnt_y]
# Index: []
#
# [0 rows x 32 columns]

# %%
Final_Dataset= Final_Dataset.sort_values(by='instant', ascending=True).reset_index(drop=True)

# %%
Final_Dataset
# Out:
#       instant     dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0           1 2011-01-01     1.0  0.0   1.0  0.0   False       -1         1.0
# 1           1        NaT     NaN  NaN   NaN  NaN     NaN       -1         NaN
# 2           2        NaT     NaN  NaN   NaN  NaN     NaN       -1         NaN
# 3           2 2011-01-01     1.0  0.0   1.0  1.0   False       -1         1.0
# 4           3 2011-01-01     1.0  0.0   1.0  2.0   False       -1         1.0
# ...       ...        ...     ...  ...   ...  ...     ...      ...         ...
# 1605      996 2011-02-14     1.0  0.0   2.0  3.0   False       -1         1.0
# 1606      997 2011-02-14     1.0  0.0   2.0  4.0   False       -1         1.0
# 1607      998 2011-02-14     1.0  0.0   2.0  5.0   False       -1         1.0
# 1608      999 2011-02-14     1.0  0.0   2.0  6.0   False       -1         1.0
# 1609     1000 2011-02-14     1.0  0.0   2.0  7.0   False       -1         1.0
#
# ...

# %%
# Check for NaN values in the entire DataFrame
print(Final_Dataset.isna().sum())

# Check for NaN values in specific columns
print(Final_Dataset['weekday'].isna().sum())
# Out:
# instant          0
# dteday         610
# season         610
# yr             610
# mnth           610
# hr             610
# holiday        610
# weekday       1610
# weathersit     610
# temp           610
# Unnamed: 0    1000
# atemp          621
# hum            610
# windspeed      610
# casual         610
# registered     610
# cnt            610
# dtype: int64
# 1610

# %%
Final_Dataset.tail()
# Out:
#       instant     dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 1605      996 2011-02-14     1.0  0.0   2.0  3.0   False       -1         1.0
# 1606      997 2011-02-14     1.0  0.0   2.0  4.0   False       -1         1.0
# 1607      998 2011-02-14     1.0  0.0   2.0  5.0   False       -1         1.0
# 1608      999 2011-02-14     1.0  0.0   2.0  6.0   False       -1         1.0
# 1609     1000 2011-02-14     1.0  0.0   2.0  7.0   False       -1         1.0
#
#       temp  Unnamed: 0   atemp   hum  windspeed  casual  registered   cnt
# 1605  0.34         NaN  0.3182  0.46     0.2239     1.0         1.0   2.0
# 1606  0.32         NaN  0.3030  0.53     0.2836     0.0         2.0   2.0
# 1607  0.32         NaN  0.3030  0.53     0.2836     0.0         3.0   3.0
# 1608  0.34         NaN  0.3030  0.46     0.2985     1.0        25.0  26.0
# 1609  0.34         NaN  0.3030  0.46     0.2985     2.0        96.0  98.0

# %%
Final_Dataset.shape
# Out:
# (1610, 17)

# %%
Final_Dataset.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'hum', 'windspeed', 'casual', 'registered', 'cnt',
#        'atemp'],
#       dtype='object')

# %%
Final_Dataset.info() #Datatype Summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1610 non-null   int64
#  1   dteday      1000 non-null   datetime64[ns]
#  2   season      1000 non-null   float64
#  3   yr          1000 non-null   float64
#  4   mnth        1000 non-null   float64
#  5   hr          1000 non-null   float64
#  6   holiday     1000 non-null   object
#  7   weekday     0 non-null      category
#  8   weathersit  1000 non-null   float64
#  9   temp        1000 non-null   float64
#  10  Unnamed: 0  610 non-null    float64
#  11  atemp       989 non-null    float64
#  12  hum         1000 non-null   float64
#  13  windspeed   1000 non-null   float64
#  14  casual      1000 non-null   float64
#  15  registered  1000 non-null   float64
#  16  cnt         1000 non-null   float64
# ...

# %%
print("Unique values in casual column: ", Final_Dataset['casual'].nunique())
print("Unique values in cnt column: ", Final_Dataset['cnt'].nunique())
print("Unique values in dteday column: ", Final_Dataset['dteday'].nunique())
# Out:
# Unique values in casual column:  42
# Unique values in cnt column:  191
# Unique values in dteday column:  45

# %%
Final_Dataset.isnull().sum()
# Out:
# instant          0
# dteday         610
# season         610
# yr             610
# mnth           610
# hr             610
# holiday        610
# weekday        610
# weathersit     610
# temp            11
# hum            610
# windspeed      610
# casual         610
# registered     610
# cnt            610
# atemp         1220
# dtype: int64

# %%
Final_Dataset.duplicated().sum()  # Duplicated Data
# Out:
# 0

# %%
# Create Line plot for hourly count for each month
plt.figure(figsize=(14,6))
q=sns.lineplot(data=Final_Dataset, x='hr', y='cnt', hue='mnth', palette='dark')

months={1: 'January', 2: 'February'}
handles, labels= q.get_legend_handles_labels()

labels = [months[int(label)] for label in labels]

q.legend(handles, labels, title= 'month')

plt.xlabel('Hour of the day')
plt.ylabel('Total count')
plt.title('Hourly Countof Rentals for January & February')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[297], line 8
#       5 months={1: 'January', 2: 'February'}
#       6 handles, labels= q.get_legend_handles_labels()
# ----> 8 labels = [months[int(label)] for label in labels]
#      10 q.legend(handles, labels, title= 'month')
#      12 plt.xlabel('Hour of the day')
#
# ValueError: invalid literal for int() with base 10: '1.0'

# %%
Final_Dataset[['weekday','cnt','mnth']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   weekday  1000 non-null   float64
#  1   cnt      1000 non-null   float64
#  2   mnth     1000 non-null   float64
# dtypes: float64(3)
# memory usage: 37.9 KB

# %%
# Define month mapping
months = {1: 'January', 2: 'February'}

# Define weekday order
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Ensure weekday column is ordered
Final_Dataset['weekday'] = pd.Categorical(Final_Dataset['weekday'], categories=weekday_order, ordered=True)

# Sort by weekday to ensure order in plot
Final_Dataset = Final_Dataset.sort_values(by='weekday')

# Create the bar plot
plt.figure(figsize=(14, 6))
l = sns.barplot(data=Final_Dataset, x='weekday', y='cnt', hue='mnth', palette='dark', estimator=sum)

# Adjust legend labels (mapping numbers to month names)
handles, labels = l.get_legend_handles_labels()

# Convert numeric labels to month names
#labels = [months[int(label)] for label in labels]
labels = [months[int(float(label))] for label in labels]
# Update the legend with correct month names
l.legend(handles, labels, title='Month')

# Labeling and formatting
plt.xlabel('Weekday')
plt.ylabel('Total Rentals')
plt.title('Total Rentals per Weekday for January & February')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
Final_Dataset.describe()
# Out:
#            instant                      dteday  season      yr         mnth  \
# count  1610.000000                        1000  1000.0  1000.0  1000.000000
# mean    426.618012  2011-01-22 15:56:09.600000     1.0     0.0     1.312000
# min       1.000000         2011-01-01 00:00:00     1.0     0.0     1.000000
# 25%     202.000000         2011-01-11 00:00:00     1.0     0.0     1.000000
# 50%     403.000000         2011-01-22 00:00:00     1.0     0.0     1.000000
# 75%     604.000000         2011-02-03 00:00:00     1.0     0.0     2.000000
# max    1000.000000         2011-02-14 00:00:00     1.0     0.0     2.000000
# std     269.261437                         NaN     0.0     0.0     0.463542
#
#                 hr   weathersit         temp          hum    windspeed  \
# count  1000.000000  1000.000000  1599.000000  1000.000000  1000.000000
# mean     11.753000     1.480000     0.203665     0.582480     0.194931
# ...

# %%
Final_Dataset.head()
# Out:
#    instant     dteday  season   yr  mnth   hr holiday weekday  weathersit  \
# 0        1 2011-01-01     1.0  0.0   1.0  0.0   False     NaN         1.0
# 1        1        NaT     NaN  NaN   NaN  NaN     NaN     NaN         NaN
# 2        2        NaT     NaN  NaN   NaN  NaN     NaN     NaN         NaN
# 3        2 2011-01-01     1.0  0.0   1.0  1.0   False     NaN         1.0
# 4        3 2011-01-01     1.0  0.0   1.0  2.0   False     NaN         1.0
#
#      temp   hum  windspeed  casual  registered   cnt  atemp
# 0  0.2400   NaN        NaN     NaN         NaN   NaN    NaN
# 1  0.2879  0.81        0.0     3.0        13.0  16.0    NaN
# 2  0.2727  0.80        0.0     8.0        32.0  40.0    NaN
# 3  0.2200   NaN        NaN     NaN         NaN   NaN    NaN
# 4  0.2200   NaN        NaN     NaN         NaN   NaN    NaN

# %%
Final_Dataset.tail()
# Out:
#       instant     dteday  season   yr  mnth   hr holiday weekday  weathersit  \
# 1605      996 2011-02-14     1.0  0.0   2.0  3.0   False     NaN         1.0
# 1606      997 2011-02-14     1.0  0.0   2.0  4.0   False     NaN         1.0
# 1607      998 2011-02-14     1.0  0.0   2.0  5.0   False     NaN         1.0
# 1608      999 2011-02-14     1.0  0.0   2.0  6.0   False     NaN         1.0
# 1609     1000 2011-02-14     1.0  0.0   2.0  7.0   False     NaN         1.0
#
#       temp   hum  windspeed  casual  registered   cnt   atemp
# 1605  0.34  0.46     0.2239     1.0         1.0   2.0  0.3182
# 1606  0.32  0.53     0.2836     0.0         2.0   2.0  0.3030
# 1607  0.32  0.53     0.2836     0.0         3.0   3.0  0.3030
# 1608  0.34  0.46     0.2985     1.0        25.0  26.0  0.3030
# 1609  0.34  0.46     0.2985     2.0        96.0  98.0  0.3030

# %%
Final_Dataset.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp', 'hum', 'windspeed', 'casual', 'registered', 'cnt',
#        'atemp'],
#       dtype='object')

# %%
Final_Dataset.shape
# Out:
# (1610, 16)

# %%
# Step 3: Save the merged dataset to a new CSV file
Final_Dataset.to_csv('merged_df1.csv', index=False)

# %%
# # Step 2: Merge the datasets. Perform the merge (inner join by default)
Final_dataset_1 = pd.merge(df_combined, Final_Dataset, on='instant', how= 'inner')

# %%
Final_dataset_1.describe
# Out:
# <bound method NDFrame.describe of       instant   dteday_x  season_x  yr_x  mnth_x  hr_x holiday_x  weekday_x  \
# 0           1 2011-01-01       1.0   0.0     1.0   0.0     False        6.0
# 1           1 2011-01-01       1.0   0.0     1.0   0.0     False        6.0
# 2           2 2011-01-01       1.0   0.0     1.0   1.0     False        6.0
# 3           2 2011-01-01       1.0   0.0     1.0   1.0     False        6.0
# 4           3 2011-01-01       1.0   0.0     1.0   2.0     False        6.0
# ...       ...        ...       ...   ...     ...   ...       ...        ...
# 2435      608        NaT       NaN   NaN     NaN   NaN       NaN        NaN
# 2436      609        NaT       NaN   NaN     NaN   NaN       NaN        NaN
# 2437      609        NaT       NaN   NaN     NaN   NaN       NaN        NaN
# 2438      610        NaT       NaN   NaN     NaN   NaN       NaN        NaN
# 2439      610        NaT       NaN   NaN     NaN   NaN       NaN        NaN
#
# ...
